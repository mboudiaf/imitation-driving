# %%
using NGSIM
using AutomotiveDrivingModels
using AutoViz
# Out:
# ┌ Info: Recompiling stale cache file C:\Users\Ianis\.julia\compiled\v0.7\NGSIM\unWOy.ji for NGSIM [195157bc-cedd-5875-9ea7-7cfb75f30b3c]
# └ @ Base loading.jl:1185
# ┌ Warning: Package NGSIM does not have AutomotiveDrivingModels in its dependencies:
# │ - If you have NGSIM checked out for development and have
# │   added AutomotiveDrivingModels as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with NGSIM
# └ Loading AutomotiveDrivingModels into NGSIM from project dependency, future warnings for NGSIM are suppressed.
# WARNING: importing deprecated binding Base.Pkg into NGSIM.
# WARNING: Base.Pkg is deprecated, run `using Pkg` instead
#   likely near C:\Users\Ianis\.julia\dev\NGSIM\src\roadway.jl:199
# ┌ Warning: `Pkg.dir(pkgname, paths...)` is deprecated; instead, do `import NGSIM; joinpath(dirname(pathof(NGSIM)), "..", paths...)`.
# ...

# %%
render(ROADWAY_LANKERSHIM)
# Out:
# Cairo.CairoSurfaceBase{UInt32}(Ptr{Nothing} @0x000000001367c430, 1000.0, 600.0)

# %%
render(ROADWAY_LANKERSHIM, cam=StaticCamera(VecE2(1966600, 570950), 3.0))
# Out:
# Cairo.CairoSurfaceBase{UInt32}(Ptr{Nothing} @0x000000001367bf80, 1000.0, 600.0)

# %%
td1 = load_trajdata(1)
# scene = get!(Scene(500), td1, 20)
# render(scene, ROADWAY_LANKERSHIM)
# Out:
# Trajdata(11207 frames)

# %%
scene = get!(Scene(10000), td1, 8400)
render(scene, ROADWAY_LANKERSHIM, cam=StaticCamera(VecE2(1966600, 571000), 2.0))
# Out:
# Cairo.CairoSurfaceBase{UInt32}(Ptr{Nothing} @0x000000001367cc00, 1000.0, 600.0)

# %%
# using Interact
# scene = Scene(500)
# @manipulate for i in 1000:2000
#     render(get!(scene, td1, i), ROADWAY_101, cam=StaticCamera(VecE2(1966400, 570900), 5.0))
# end

# %%
td1.defs
